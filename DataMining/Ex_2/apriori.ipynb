# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datamining/Ex-2_Transactions.csv.csv

# %%
#Import the necessary libraries 



import pandas as pd

# %%
#Load the dataset 

store_data = pd.read_csv('/mnt/F84E0CA94E0C632C/CollegeClass/SEM_6/College/DataMining/Ex_2/dataset.csv', header=None)

# %%
#Print the records in dataset 

print (store_data); 

print(store_data.shape);
# Out:
#       0    1      2        3      4     5       6
# 0  Milk  Egg  Bread      NaN    NaN   NaN     NaN
# 1   NaN  Egg    NaN  Popcorn  Chips  Beer     NaN
# 2   NaN  Egg  Bread      NaN  Chips   NaN     NaN
# 3  Milk  Egg  Bread  Popcorn  Chips  Beer     NaN
# 4  Milk  NaN  Bread      NaN    NaN  Beer     NaN
# 5   NaN  Egg  Bread      NaN    NaN  Beer     NaN
# 6  Milk  NaN  Bread      NaN  Chips   NaN     NaN
# 7  Milk  Egg  Bread      NaN  Chips   NaN  Butter
# 8  Milk  Egg    NaN      NaN  Chips   NaN  Butter
# (9, 7)

# %%
#Convert the dataframe into lists 

records = [] 

for i in range(len(store_data)): 

    records.append([str(store_data.values [i,j]) for j in range(0, 6)]) 
print(records)
# Out:
# [['Milk', 'Egg', 'Bread', 'nan', 'nan', ' NaN'], ['nan', 'Egg', 'nan', 'Popcorn', 'Chips', 'Beer'], ['nan', 'Egg', 'Bread', 'nan', 'Chips', ' NaN'], ['Milk', 'Egg', 'Bread', 'Popcorn', 'Chips', 'Beer'], ['Milk', 'nan', 'Bread', 'nan', 'nan', 'Beer'], ['nan', 'Egg', 'Bread', 'nan', 'nan', 'Beer'], ['Milk', 'nan', 'Bread', 'nan', 'Chips', ' NaN'], ['Milk', 'Egg', 'Bread', 'nan', 'Chips', ' NaN'], ['Milk', 'Egg', 'nan', 'nan', 'Chips', ' NaN']]

# %%
#Fit the data to the apriori model 

from apyori import apriori 

association_rules = apriori (records,min_support=0.3, min_confidence=0.6, min_lift=1.1, min_length=2)

# %%
#Convert association_rules into lists 

association_results = list(association_rules)

# %%
# Print the number of rules 

print (len(association_results))
# Out:
# 20

# %%
#Print the association rules 

print (association_results)
# Out:
# [RelationRecord(items=frozenset({' NaN', 'Chips'}), support=0.4444444444444444, ordered_statistics=[OrderedStatistic(items_base=frozenset({' NaN'}), items_add=frozenset({'Chips'}), confidence=0.7999999999999999, lift=1.2), OrderedStatistic(items_base=frozenset({'Chips'}), items_add=frozenset({' NaN'}), confidence=0.6666666666666666, lift=1.2)]), RelationRecord(items=frozenset({' NaN', 'Milk'}), support=0.4444444444444444, ordered_statistics=[OrderedStatistic(items_base=frozenset({' NaN'}), items_add=frozenset({'Milk'}), confidence=0.7999999999999999, lift=1.2), OrderedStatistic(items_base=frozenset({'Milk'}), items_add=frozenset({' NaN'}), confidence=0.6666666666666666, lift=1.2)]), RelationRecord(items=frozenset({' NaN', 'nan'}), support=0.5555555555555556, ordered_statistics=[OrderedStatistic(items_base=frozenset({' NaN'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.125), OrderedStatistic(items_base=frozenset({'nan'}), items_add=frozenset({' NaN'}), confidence=0.6250000000000001, lift=1.1250000000000002)]), RelationRecord(items=frozenset({'Bread', ' NaN', 'Chips'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset({' NaN'}), items_add=frozenset({'Bread', 'Chips'}), confidence=0.6, lift=1.35), OrderedStatistic(items_base=frozenset({'Bread', ' NaN'}), items_add=frozenset({'Chips'}), confidence=0.75, lift=1.125), OrderedStatistic(items_base=frozenset({'Bread', 'Chips'}), items_add=frozenset({' NaN'}), confidence=0.75, lift=1.3499999999999999)]), RelationRecord(items=frozenset({'Bread', ' NaN', 'Milk'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Bread', ' NaN'}), items_add=frozenset({'Milk'}), confidence=0.75, lift=1.125)]), RelationRecord(items=frozenset({'Bread', ' NaN', 'nan'}), support=0.4444444444444444, ordered_statistics=[OrderedStatistic(items_base=frozenset({' NaN'}), items_add=frozenset({'Bread', 'nan'}), confidence=0.7999999999999999, lift=1.2), OrderedStatistic(items_base=frozenset({'Bread', ' NaN'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.125), OrderedStatistic(items_base=frozenset({'Bread', 'nan'}), items_add=frozenset({' NaN'}), confidence=0.6666666666666666, lift=1.2)]), RelationRecord(items=frozenset({' NaN', 'Chips', 'Egg'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset({' NaN', 'Egg'}), items_add=frozenset({'Chips'}), confidence=0.75, lift=1.125)]), RelationRecord(items=frozenset({' NaN', 'Milk', 'Chips'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset({' NaN'}), items_add=frozenset({'Milk', 'Chips'}), confidence=0.6, lift=1.35), OrderedStatistic(items_base=frozenset({' NaN', 'Chips'}), items_add=frozenset({'Milk'}), confidence=0.75, lift=1.125), OrderedStatistic(items_base=frozenset({' NaN', 'Milk'}), items_add=frozenset({'Chips'}), confidence=0.75, lift=1.125), OrderedStatistic(items_base=frozenset({'Milk', 'Chips'}), items_add=frozenset({' NaN'}), confidence=0.75, lift=1.3499999999999999)]), RelationRecord(items=frozenset({' NaN', 'Chips', 'nan'}), support=0.4444444444444444, ordered_statistics=[OrderedStatistic(items_base=frozenset({' NaN'}), items_add=frozenset({'Chips', 'nan'}), confidence=0.7999999999999999, lift=1.4399999999999997), OrderedStatistic(items_base=frozenset({'Chips'}), items_add=frozenset({' NaN', 'nan'}), confidence=0.6666666666666666, lift=1.2), OrderedStatistic(items_base=frozenset({' NaN', 'Chips'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.125), OrderedStatistic(items_base=frozenset({' NaN', 'nan'}), items_add=frozenset({'Chips'}), confidence=0.7999999999999999, lift=1.2), OrderedStatistic(items_base=frozenset({'Chips', 'nan'}), items_add=frozenset({' NaN'}), confidence=0.7999999999999999, lift=1.4399999999999997)]), RelationRecord(items=frozenset({' NaN', 'Milk', 'Egg'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset({' NaN'}), items_add=frozenset( ...
